# %%
import pandas as pd
import numpy as np

# %%
nota_pratos = pd.read_csv('Cuisine_rating.csv')

# %%
nota_pratos.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating Often A S
# 0               4             4.5        No
# 1               1             1.0        No
# ...

# %%
nota_pratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User ID         200 non-null    int64
#  1   Area code       200 non-null    int64
#  2   Location        200 non-null    object
#  3   Gender          200 non-null    object
#  4   YOB             200 non-null    int64
#  5   Marital Status  200 non-null    object
#  6   Activity        200 non-null    object
#  7   Budget          200 non-null    int64
#  8   Cuisines        200 non-null    object
#  9   Alcohol         200 non-null    object
#  10  Smoker          200 non-null    object
#  11  Food Rating     200 non-null    int64
#  12  Service Rating  200 non-null    int64
#  13  Overall Rating  200 non-null    float64
#  14  Often A S       200 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 23.6+ KB

# %%
nota_pratos['Location']
# Out:
# 0      Upper East Side,NY
# 1           St. George,NY
# 2      Upper West Side,NY
# 3      Upper East Side,NY
# 4         Central Park,NY
#               ...
# 195         St. George,NY
# 196    Upper West Side,NY
# 197         St. George,NY
# 198         St. George,NY
# 199    Upper East Side,NY
# Name: Location, Length: 200, dtype: object

# %%
nota_pratos['Location'].value_counts()
# Out:
# Location
# St. George,NY         46
# Upper East Side,NY    30
# Riverdale,NY          28
# Central Park,NY       24
# China Town, NY        22
# Market City, NY       20
# Upper West Side,NY    18
# Central Park,ny        8
# Market City, MY        2
# Cedar Hill, NY         2
# Name: count, dtype: int64

# %%
nota_pratos[nota_pratos['Overall Rating'] == 5.0]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 12        13        123       St. George,NY  Female  2006         Single
# 23        24        154     Market City, NY    Male  1974       Divorced
# 34        35        129     Central Park,NY    Male  2001       Divorced
# 41        42        154     Market City, NY  Female  1967         Single
# 50        51        107        Riverdale,NY  Female  2007         Single
# 56        57        123       St. George,NY  Female  1981       Divorced
# 61        62        122  Upper West Side,NY  Female  1955       Divorced
# 62        63        123       St. George,NY    Male  2002         Single
# 64        65        129     Central Park,NY  Female  1996         Single
# 78        79        111      China Town, NY    Male  1965        Married
# 84        85        153  Upper East Side,NY  Female  1978       Divorced
# ...

# %%
nota_pratos['Food Rating'].value_counts()
# Out:
# Food Rating
# 5    53
# 3    46
# 2    35
# 4    35
# 1    31
# Name: count, dtype: int64

# %%
nota_pratos[nota_pratos['Overall Rating'] == 5.0]['Budget'].mean()
# Out:
# 3.689655172413793
